# %% [markdown]
# # 스트리밍 API 응답
# 기본적으로 OpenAI API에 요청을 보내면 모델의 전체 출력을 생성한 후 단일 HTTP 응답으로 다시 전송합니다. 긴 출력을 생성할 경우 응답을 기다리는 데 시간이 걸릴 수 있습니다.
# 스트리밍 응답을 사용하면 전체 응답을 생성하는 동안 모델 출력의 시작 부분을 인쇄하거나 처리할 수 있습니다.
#
# 응답 스트리밍을 시작하려면 stream=True응답 엔드포인트에 대한 요청을 설정합니다.

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv()) # read local .env file
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()

Model = "gpt-4.1-nano"

# %%
stream = client.responses.create(
    model=Model,
    input=[
        {
            "role": "user",
            "content": "성경의 창세기 시작 부분을 1000 글자내에서 알려줘.",
        },
    ],
    stream=True,
)

for chunk in stream:
    if chunk.type == 'response.output_text.delta':
        print(chunk.delta, end="")
# Out:
# 물론입니다. 성경의 창세기 시작 부분을 1000자 내외로 요약해 드리겠습니다.
#
# ---
#
#  태초에 하나님이 계셨음을 전하며 시작합니다. 하나님은 태초에 하늘과 땅을 창조하시고, 땅은 형체도 없고 공허하며 흑암이 깊음 위에 있었다고 합니다. 하나님은 말씀으로 빛을 창조하시고, 빛이 어둠 가운데 나뉘게 하셨습니다. 이후 하늘을 만들어 하늘과 땅을 구별하시고, 땅 위에 육지와 식물들을, 하늘에는 해와 달과 별들을 배치하셨습니다.
#
# 다와 하늘에 생물을 창조하시고, 땅에는 각종 동물과 사람을 만드셨습니다. 사람은 하나님의 형상대로, 남자와 여자로 창조되어 하나님께서 그들에게 땅을 다스리고 생육하며 번성하라는 명령을 내리셨습니다. 그리고 하나님은 모든 것을 보시고 매우 좋다고 평가하셨습니다.
#
# 입니다. 성경의 시작 부분은 하나님의 창조와 인간의 최초 창조를 통해 신의 권능과 의도를 보여줍니다.
#
# ---
#
# 거나 특정 부분을 원하시면 알려주세요!
