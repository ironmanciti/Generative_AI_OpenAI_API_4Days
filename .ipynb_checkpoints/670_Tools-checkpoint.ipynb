# %% [markdown]
# # 코드 인터프리터 (Code Interpreter)
# 모델이 Python을 작성하고 실행하여 문제를 해결할 수 있도록 지원합니다.
#
# 코드 인터프리터 도구를 사용하면 모델이 샌드박스 환경에서 Python 코드를 작성하고 실행하여 데이터 분석, 코딩, 수학 등의 복잡한 문제를 해결할 수 있습니다. 다음과 같은 용도로 사용할 수 있습니다.
#
# - 다양한 데이터 및 형식이 포함된 파일 처리
# - 데이터와 그래프 이미지가 포함된 파일 생성
# - 문제 해결을 위해 반복적으로 코드를 작성하고 실행합니다. 예를 들어, 실행에 실패한 코드를 작성한 모델은 성공할 때까지 해당 코드를 계속 다시 작성하고 실행할 수 있습니다.
#
# 최신 추론 모델인 o3와 o4-mini는 코드 인터프리터를 사용하여 이미지를 심층적으로 이해하도록 훈련되었습니다. 자르기, 확대, 회전 및 기타 이미지 처리 기술을 수행하여 시각적 지능을 향상시킬 수 있습니다.
#
# 코드 인터프리터는 컨테이너 생성당 $0.03의 요금이 부과됩니다. 사용료에 대한 자세한 내용은 가격 페이지를 참조하세요.

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv()) # read local .env file
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()

Model = "gpt-4.1-nano"

# %%
resp = client.responses.create(
  model=Model,
  tools=[
    {
      "type": "code_interpreter",
      "container": { "type": "auto" }
    }
  ],
  instructions="당신은 개인 수학 과외 선생님입니다. 수학 문제가 나오면 코드를 작성하고 실행하여 질문에 답하세요.",
  input="3x + 11 = 14 방정식을 풀어야 합니다. 도와주실 수 있나요?",
)

print(resp.output_text)
# Out:
# 네, 물론 도와드릴게요! 주어진 방정식은 \( 3x + 11 = 14 \)입니다. 이 방정식을 풀기 위해서 \(x\)에 대해 정리하면 됩니다. 먼저 11을 왼쪽으로 옮기고, 그 다음에 3으로 나누면 됩니다. 이를 파이썬 코드를 통해 풀어보겠습니다.이 방정식의 해는 \(x = 1\)입니다. 도움이 되었나요?

# %%
resp
# Out:
# Response(id='resp_683d49d4f7388190ad219471c2336aa30b183fdb0988a6c6', created_at=1748847060.0, error=None, incomplete_details=None, instructions='당신은 개인 수학 과외 선생님입니다. 수학 문제가 나오면 코드를 작성하고 실행하여 질문에 답하세요.', metadata={}, model='gpt-4.1-nano-2025-04-14', object='response', output=[ResponseOutputMessage(id='msg_683d49d6ac848190a141d577329953690b183fdb0988a6c6', content=[ResponseOutputText(annotations=[], text='네, 물론 도와드릴게요! 주어진 방정식은 \\( 3x + 11 = 14 \\)입니다. 이 방정식을 풀기 위해서 \\(x\\)에 대해 정리하면 됩니다. 먼저 11을 왼쪽으로 옮기고, 그 다음에 3으로 나누면 됩니다. 이를 파이썬 코드를 통해 풀어보겠습니다.', type='output_text')], role='assistant', status='completed', type='message'), ResponseOutputMessage(id='ci_683d49d79bd081909f6e91138170707c0b183fdb0988a6c6', content=None, role=None, status='completed', type='code_interpreter_call', code="from sympy import symbols, Eq, solve\n\n# 변수 선언\nx = symbols('x')\n\n# 방정식 정의\nequation = Eq(3*x + 11, 14)\n\n# 방정식 풀기\nsolution = solve(equation, x)\nsolution", container_id='cntr_683d49d671988190b52d1203313789ee03a9fb93d90c10b3', outputs=None), ResponseOutputMessage(id='msg_683d49ddac8c8190b06a89bd42a367230b183fdb0988a6c6', content=[ResponseOutputText(annotations=[], text='이 방정식의 해는 \\(x = 1\\)입니다. 도움이 되었나요?', type='output_text')], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FileSearchTool(type='code_interpreter', vector_store_ids=None, filters=None, max_num_results=None, ranking_options=None, container={'type': 'auto'})], top_p=1.0, max_output_tokens=None, previous_response_id=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text')), truncation='disabled', usage=ResponseUsage(input_tokens=737, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=173, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=910), user=None, background=False, service_tier='default', store=True)

# %%
print(resp.output[0].content[0].text)
# Out:
# 네, 물론 도와드릴게요! 주어진 방정식은 \( 3x + 11 = 14 \)입니다. 이 방정식을 풀기 위해서 \(x\)에 대해 정리하면 됩니다. 먼저 11을 왼쪽으로 옮기고, 그 다음에 3으로 나누면 됩니다. 이를 파이썬 코드를 통해 풀어보겠습니다.

# %%
print(resp.output[1].code)
# Out:
# from sympy import symbols, Eq, solve
#
# # 변수 선언
# x = symbols('x')
#
# # 방정식 정의
# equation = Eq(3*x + 11, 14)
#
# # 방정식 풀기
# solution = solve(equation, x)
# solution

# %% [markdown]
# # 파일 검색
# 모델이 응답을 생성하기 전에 관련 정보를 파일에서 검색할 수 있도록 합니다.
# 파일 검색은 Responses API에서 제공되는 도구입니다. 모델이 시맨틱 및 키워드 검색을 통해 이전에 업로드된 파일의 지식 기반에서 정보를 검색할 수 있도록 합니다. 벡터 저장소를 생성하고 파일을 업로드하면, 모델이 이러한 지식 기반 또는 벡터 저장소에 접근할 수 있도록 하여 모델의 내재된 지식을 강화할 수 있습니다.
#
# 이 도구는 OpenAI에서 관리하는 호스팅 도구이므로, 실행을 처리하기 위해 코드를 직접 구현할 필요가 없습니다. 모델이 이 도구를 사용하기로 결정하면 자동으로 도구를 호출하여 파일에서 정보를 검색하고 출력을 반환합니다.

# %%
# "Financial Statements"라는 벡터 스토어 생성
vector_store = client.vector_stores.create(name="Financial Statements")
 
# OpenAI에 업로드할 파일 준비
file_paths = ["재무제표/goog-10k.pdf", "재무제표/brka-10k.pdf"]
file_streams = [open(path, "rb") for path in file_paths]
 
# 업로드 및 폴링 SDK 도우미를 사용하여 파일을 업로드하고 벡터 스토어에 추가,
# 파일 배치의 완료 상태를 폴링합니다.
file_batch = client.vector_stores.file_batches.upload_and_poll(
  vector_store_id=vector_store.id, files=file_streams
)
 
# 이 작업의 결과를 보기 위해 상태 및 파일 개수를 출력할 수 있습니다.
print(file_batch.status)
print(file_batch.file_counts)
# Out:
# completed
# FileCounts(cancelled=0, completed=2, failed=0, in_progress=0, total=2)

# %%
response = client.responses.create(
    model=Model,
    input="2023년 10월 말에 AAPL의 발행 주식 수는 얼마였나요?",
    tools=[{
        "type": "file_search",
        "vector_store_ids": [vector_store.id]
    }]
)
print(response)
# Out:
# Response(id='resp_683d49ee9dd481959064eed625ff6ff40f279dd88ed3e889', created_at=1748847086.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-nano-2025-04-14', object='response', output=[ResponseFileSearchToolCall(id='fs_683d49ef026c8195bd4672200138a2870f279dd88ed3e889', queries=['2023년 10월 말 AAPL의 발행 주식 수'], status='completed', type='file_search_call', results=None), ResponseOutputMessage(id='msg_683d49f0872481959f7eee78f9834e160f279dd88ed3e889', content=[ResponseOutputText(annotations=[AnnotationFileCitation(file_id='file-Ra2dEiBd7VviWnvisJiDaN', index=206, type='file_citation', filename='brka-10k.pdf')], text='2023년 10월 말에 AAPL의 발행 주식 수에 관한 구체적인 수치는 제공된 자료에서 확인할 수 없습니다. 다만, 2023년 1월 26일 기준으로, 애플(Apple Inc.)의 Class A 주식은 297,117,506주, Class B 주식은 47,369,687주, 그리고 Class C 자본 주식은 346,933,134주가 각각 발행되어 있음을 확인할 수 있습니다.', type='output_text')], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FileSearchTool(type='file_search', vector_store_ids=['vs_683d49de56448191aa945ec4acb74b5d'], filters=None, max_num_results=20, ranking_options=RankingOptions(ranker='auto', score_threshold=0.0))], top_p=1.0, max_output_tokens=None, previous_response_id=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text')), truncation='disabled', usage=ResponseUsage(input_tokens=17793, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=150, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=17943), user=None, background=False, service_tier='default', store=True)

# %%
response.output_text
# Out:
# '2023년 10월 말에 AAPL의 발행 주식 수에 관한 구체적인 수치는 제공된 자료에서 확인할 수 없습니다. 다만, 2023년 1월 26일 기준으로, 애플(Apple Inc.)의 Class A 주식은 297,117,506주, Class B 주식은 47,369,687주, 그리고 Class C 자본 주식은 346,933,134주가 각각 발행되어 있음을 확인할 수 있습니다.'

# %%
response = client.responses.create(
    model=Model,
    input="2023년 Google의 당기 순이익은 얼마였나요? BERKSHIRE HATHAWAY INC. 와 어느 쪽의 당기 순이익이 더 많았나요?",
    tools=[{
        "type": "file_search",
        "vector_store_ids": [vector_store.id]
    }]
)

# %%
print(response.output_text)
# Out:
# 2023년 Google의 당기 순이익 관련 정보는 제공된 자료에서 찾을 수 없으며, 대신 Berkshire Hathaway Inc.의 2023년 당기 순이익은 약 42,521백만 달러로 나타났습니다. 따라서, 2023년 기준으로 Berkshire Hathaway의 당기 순이익이 Google보다 훨씬 높았던 것으로 보입니다.
#
# Google의 2022년 또는 2023년 순이익 수치는 제공된 자료에 포함되어 있지 않기 때문에 정확한 비교는 어려우나, 2023년 Berkshire Hathaway의 순이익이 더 많았던 점은 확실합니다.

# %%
# step2) 새 벡터 스토어 생성
vector_store = client.vector_stores.create(name="기업분석보고서")
 
# OpenAI에 업로드할 파일 준비
file_paths = ["재무제표/네이버.pdf", "재무제표/LG엔솔.pdf"]
file_streams = [open(path, "rb") for path in file_paths]
 
# 업로드 및 폴링 SDK 도우미를 사용하여 파일을 업로드하고 벡터 스토어에 추가,
# 파일 배치의 완료 상태를 폴링합니다.
file_batch = client.vector_stores.file_batches.upload_and_poll(
  vector_store_id=vector_store.id, files=file_streams
)
 
# 이 작업의 결과를 보기 위해 상태 및 파일 개수를 출력할 수 있습니다.
print(file_batch.status)
print(file_batch.file_counts)
# Out:
# completed
# FileCounts(cancelled=0, completed=2, failed=0, in_progress=0, total=2)

# %%
response = client.responses.create(
    model=Model,
    input="LG에너지솔루션의 2024년 하반기 전망을 요약해 주세요. 에코프로비엠은 매출액이 줄은 것에 비해 왜 영업이익이 더 크게 줄어들었나요?",
    tools=[{
        "type": "file_search",
        "vector_store_ids": [vector_store.id]
    }]
)

print(response.output_text)
# Out:
# LG에너지솔루션의 2024년 하반기 전망은 전반적으로 기대는 유지하면서도 일부 부진 요인에 대한 하향 조정이 이루어졌습니다. 2분기 실적은 선도 전기차 업체들의 수요 부진과 ESS(에너지 저장 시스템) 적자로 인해 컨센서스를 하회하였으며, 특히 GM을 비롯한 전통적 완성차 업체의 노후화와 판매 부진이 변수로 작용하고 있습니다. 그러나 GM의 신차 출시와 판매 성장세는 하반기 전망에 중요한 역할을 할 것으로 기대되며, 주가는 목표주가보다 낮은 수준으로 평가되어 상승 잠재력이 남아있습니다 .
#
# 에코프로비엠이 매출액이 감소하는 가운데 영업이익이 더 크게 줄어든 원인은 여러 요인과 관련이 있습니다. 주로 원자재 가격 상승, 생산 비용 증가, 그리고 고객사(특히 2차전지 업체들의 수요 변화)에 따른 판매 구조의 어려움이 영업이익 감소를 가속시킨 것으로 보입니다. 매출이 줄면서도 영업이익이 더 크게 감소하는 현상은 고정비 부담 증가 또는 판매 단가 하락으로 인해 수익성에 타격이 가해졌기 때문일 가능성이 높습니다 .
#
# 요약하자면, LG에너지솔루션은 하반기 전기차 시장 회복 기대와 신차 판매 증대에 힘입어 성장 모멘텀을 유지하는 가운데, 글로벌 공급망과 수요 부진은 단기적 도전으로 작용할 것으로 분석됩니다. 한편, 에코프로비엠의 수익성 악화는 원가 증가와 시장 경쟁 심화에 따른 수익 구조 변화로 설명됩니다.

# %%
response = client.responses.create(
    model=Model,
    input="2023년 4분기의 네이버의 영업이익은 얼마였나요? 한화 투자 증권이 목표가를 상향 조정한 이유는 무엇인가요?",
    tools=[{
        "type": "file_search",
        "vector_store_ids": [vector_store.id]
    }]
)

print(response.output_text)
# Out:
# 2023년 4분기 네이버의 영업이익은 4055억 원으로 집계되었습니다.
#
# 한화투자증권이 네이버의 목표가를 상향 조정한 이유는, 광고와 커머스 부문의 수익성 개선세와 웹툰 엔터테인먼트 지분가치의 상향 조정이 반영되었기 때문입니다. 특히, 비용 통제 등으로 인한 이익 개선이 실적으로 나타나고 있으며, AI 기반의 광고와 커머스 성과도 기대에 부합하고 있다는 점이 핵심 요인입니다.

# %% [markdown]
# ## 실습: 코드 인터프리터와 파일 검색 도구 활용
#
# 다음과 같은 사용자 질문이 주어졌을 때, OpenAI Responses API를 이용해 코드 인터프리터와 벡터 스토어 기반 검색 도구를 적절히 활용하여 응답을 생성하는 실습을 하세요.
#
# 1. **수학 문제 풀이**
#    사용자 질문:
#
# > `"x^2 - 5x + 6 = 0 방정식의 해를 구해주세요."`
#
# - `code_interpreter` 도구를 사용하여 문제를 코드로 풀고, 결과를 사용자에게 출력하세요.
# - instructions를 사용하여 모델에게 “수학 선생님 역할”을 지정하세요.
#
#
# 2. **PDF 기반 질문 응답 (file\_search 도구)**
#    PDF 파일 `삼성전자_사업보고서.pdf`를 벡터 스토어에 업로드하고, 다음 질문에 답하도록 구현하세요:
#
# 사용자 질문:
#
# > `"2023년 삼성전자의 반도체 부문 실적 요약을 알려주세요."`
#
# - 벡터 스토어를 생성하고 파일을 업로드하는 코드
# - file\_search 도구를 통해 답을 생성하는 응답 흐름 구현
