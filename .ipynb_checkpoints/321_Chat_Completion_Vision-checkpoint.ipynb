# %% [markdown]
# # Vision
#
# - GPT-4o with image inpus
#
# - GPT-4o와 GPT-4 Turbo 모두 비전 기능을 갖추고 있습니다. 즉, 모델이 이미지를 촬영하고 그에 대한 질문에 답할 수 있습니다

# %%
import os
import openai
import sys
sys.path.append('./')

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

# %% [markdown]
# 이미지는 두 가지 주요 방법, 즉 이미지에 대한 링크를 전달하거나 요청에 base64로 인코딩된 이미지를 직접 전달하는 방법으로 모델에서 사용할 수 있습니다.

# %%
from openai import OpenAI

client = OpenAI()

Model = "gpt-4o-mini"

# %% [markdown]
# ### 이미지의 내용 설명
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg" width=300px />

# %%
url = "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg"

response = client.chat.completions.create(
  model=Model,
  messages=[
    {
      "role": "user",
      "content": [
        {"type": "text", "text": "이 이미지의 내용을 설명해줘. 한국어로 설명해줘."},
        {
          "type": "image_url",
          "image_url": {
            "url": url,
          },
        },
      ],
    }
  ],
  max_tokens=300,
)

response.to_dict()
# Out:
# {'id': 'chatcmpl-AOweG6N2iST4mYtO26sURuTxjw0yC',
#  'choices': [{'finish_reason': 'stop',
#    'index': 0,
#    'logprobs': None,
#    'message': {'content': '이미지는 푸른 풀밭과 나무들로 둘러싸인 자연 경관을 보여주고 있습니다. 가운데에는 나무로 만들어진 보행로가 있으며, 이는 풀밭을 가로지르며 이어지고 있습니다. 하늘은 맑고 푸르며, 구름이 흩어져 있는 모습이 보입니다. 전체적으로 평화롭고 고요한 느낌을 주며, 자연의 아름다움을 강조하고 있습니다.',
#     'role': 'assistant',
#     'refusal': None}}],
#  'created': 1730508680,
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'system_fingerprint': 'fp_9b78b61c52',
#  'usage': {'completion_tokens': 100,
#   'prompt_tokens': 36857,
#   'total_tokens': 36957,
#   'prompt_tokens_details': {'cached_tokens': 0},
#   'completion_tokens_details': {'reasoning_tokens': 0}}}

# %%
print(response.choices[0].message.content)
# Out:
# 이미지는 푸른 풀밭과 나무들로 둘러싸인 자연 경관을 보여주고 있습니다. 가운데에는 나무로 만들어진 보행로가 있으며, 이는 풀밭을 가로지르며 이어지고 있습니다. 하늘은 맑고 푸르며, 구름이 흩어져 있는 모습이 보입니다. 전체적으로 평화롭고 고요한 느낌을 주며, 자연의 아름다움을 강조하고 있습니다.

# %% [markdown]
# ### Base 64로 인코딩된 이미지 업로드
# 로컬에 이미지 또는 이미지 세트가 있는 경우 이를 Base 64 인코딩 형식으로 모델에 전달할 수 있습니다. 다음은 이에 대한 실제 예입니다.

# %%
import base64
import requests
from IPython.display import Image, display

# Function to encode the image
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
image_path = "data/냉장고내용물.jpg"

# Getting the base64 string
base64_image = encode_image(image_path)

display(Image(filename=image_path))

# %%
headers = {
  "Content-Type": "application/json",
  "Authorization": f"Bearer {os.environ['OPENAI_API_KEY']}"
}

payload = {
  "model": Model,
  "messages": [
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "이 이미지의 내용을 한국어로 설명해줘."
        },
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{base64_image}"
          }
        }
      ]
    }
  ],
  "max_tokens": 300
}

response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)

print(response.json())
# Out:
# {'id': 'chatcmpl-AOwhn5maihi9dJ2FG0EwRmEr7CuJW', 'object': 'chat.completion', 'created': 1730508899, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '이 이미지는 깨끗하게 정돈된 냉장고 안을 보여줍니다. 냉장고의 각 선반에는 다양한 신선한 과일과 채소가 가득합니다. 상단 선반에는 딸기, 오렌지, 사과와 같은 과일이 있고, 중간 선반에는 다양한 채소들과 시금치, 양배추, 방울토마토 등이 있습니다. 하단 선반에는 여러 종류의 채소와 과일이 담긴 용기들이 있으며, 음료수로 보이는 병들도 보입니다. 전체적으로 건강한 식재료로 가득 찬 모습을 하고 있습니다.', 'refusal': None}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 14185, 'completion_tokens': 139, 'total_tokens': 14324, 'prompt_tokens_details': {'cached_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0}}, 'system_fingerprint': 'fp_9b78b61c52'}

# %%
res = response.json()
res['choices'][0]['message']['content']
# Out:
# '이 이미지는 깨끗하게 정돈된 냉장고 안을 보여줍니다. 냉장고의 각 선반에는 다양한 신선한 과일과 채소가 가득합니다. 상단 선반에는 딸기, 오렌지, 사과와 같은 과일이 있고, 중간 선반에는 다양한 채소들과 시금치, 양배추, 방울토마토 등이 있습니다. 하단 선반에는 여러 종류의 채소와 과일이 담긴 용기들이 있으며, 음료수로 보이는 병들도 보입니다. 전체적으로 건강한 식재료로 가득 찬 모습을 하고 있습니다.'

# %% [markdown]
# ### 다중 이미지 입력
# Chat Completions API는 base64로 인코딩된 형식이나 이미지 URL로 여러 이미지 입력을 가져와 처리할 수 있습니다. 모델은 각 이미지를 처리하고 모든 이미지의 정보를 사용하여 질문에 답합니다.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg" width=300px />
#
# <img src="https://img.freepik.com/premium-photo/a-wooden-walkway-leads-to-a-green-field-with-a-mountain-in-the-background_800563-10576.jpg" width=300px />

# %%
from openai import OpenAI

client = OpenAI()
response = client.chat.completions.create(
  model=Model,
  messages=[
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "이 이미지에는 무엇이 들어있나요? 그들 사이에 어떤 차이가 있나요?",
        },
        {
          "type": "image_url",
          "image_url": {
            "url": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg",
          },
        },
        {
          "type": "image_url",
          "image_url": {
            "url": "https://img.freepik.com/premium-photo/a-wooden-walkway-leads-to-a-green-field-with-a-mountain-in-the-background_800563-10576.jpg",
          },
        },
      ],
    }
  ],
  max_tokens=300,
)

# %%
response
# Out:
# ChatCompletion(id='chatcmpl-AOwiC3v9qjXq5PxTdqzpCkzUowypg', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='첫 번째 이미지는 푸른 초원과 하늘이 있는 풍경을 보여줍니다. 나무로 만들어진 산책로가 초원 속으로 뻗어 있으며, 배경에는 나무들이 보입니다.\n\n두 번째 이미지는 나무로 된 산책로가 농장처럼 보이는 지역으로 이어지고 있으며, 밀밭이나 쌀밭으로 보이는 초록색 식물이 널리 퍼져 있습니다. 배경에는 산과 저녁 노을이 보입니다.\n\n두 이미지의 차이점은 다음과 같습니다:\n\n1. **환경**: 첫 번째 이미지는 좀 더 습기 있는 초원 지역으로 보이는 반면, 두 번째 이미지는 농업 지역입니다.\n2. **식물**: 첫 번째는 다양한 풀과 관목이 있는 초원이 보이고, 두 번째는 일정한 높이의 농작물이 있습니다.\n3. **하늘과 조명**: 첫 번째 이미지는 맑은 하늘과 밝은 낮의 조명, 두 번째 이미지는 저녁 시간대의 어두운 파란색 하늘과 따뜻한 색조가 돋보입니다. \n\n이와 같이 두 이미지는 각기 다른 자연 환경과 기분을 전달하고 있습니다.', role='assistant', function_call=None, tool_calls=None, refusal=None))], created=1730508924, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_9b78b61c52', usage=CompletionUsage(completion_tokens=265, prompt_tokens=51028, total_tokens=51293, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0}))

# %%
print(response.choices[0].message.content)
# Out:
# 첫 번째 이미지는 푸른 초원과 하늘이 있는 풍경을 보여줍니다. 나무로 만들어진 산책로가 초원 속으로 뻗어 있으며, 배경에는 나무들이 보입니다.
#
# 두 번째 이미지는 나무로 된 산책로가 농장처럼 보이는 지역으로 이어지고 있으며, 밀밭이나 쌀밭으로 보이는 초록색 식물이 널리 퍼져 있습니다. 배경에는 산과 저녁 노을이 보입니다.
#
# 두 이미지의 차이점은 다음과 같습니다:
#
# 1. **환경**: 첫 번째 이미지는 좀 더 습기 있는 초원 지역으로 보이는 반면, 두 번째 이미지는 농업 지역입니다.
# 2. **식물**: 첫 번째는 다양한 풀과 관목이 있는 초원이 보이고, 두 번째는 일정한 높이의 농작물이 있습니다.
# 3. **하늘과 조명**: 첫 번째 이미지는 맑은 하늘과 밝은 낮의 조명, 두 번째 이미지는 저녁 시간대의 어두운 파란색 하늘과 따뜻한 색조가 돋보입니다.
#
# 이와 같이 두 이미지는 각기 다른 자연 환경과 기분을 전달하고 있습니다.
