# %% [markdown]
# # Simplified Vision Transformer
#
# ViT를 이용한 CIFAR-100(Canadian Institute for Advanced Research, 총 100개의 클래스 또는 범주) 이미지 분류
#
# ### GPU 필요하므로 Colab에서 실행

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt

# %%
num_classes = 100
input_shape = (32, 32, 3)
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar100.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 6s 0us/step
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
plt.figure(figsize=(5, 5))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(X_train[i])
    plt.title(f"Class: {y_train[i][0]}")
    plt.axis('off')
plt.tight_layout()

# %% [markdown]
# CIFAR-100 데이터셋은 이미지 크기가 32x32로 상대적으로 작은 이미지로 구성되어 있습니다. 따라서 Vision Transformer 모델을 이 데이터셋에 적용하려면 32x32 이미지를 224x224 크기로 변경하여 패치로 분할하는 것이 일반적입니다. 이렇게 하면 모델이 더 큰 패치에서 특징을 추출하고 이미지 내의 다양한 정보를 고려할 수 있게 됩니다.

# %%
# 배치 크기 (한 번에 처리할 이미지 수)
batch_size = 256

# 이미지 크기 (가로와 세로 크기가 동일한 이미지)
image_size = 224

# 이미지를 나눌 패치(patch) 크기
patch_size = 32

# 이미지를 패치로 나눌 때 생성되는 패치 개수
num_patches = (image_size // patch_size) ** 2

# D (임베딩 차원 및 어텐션 헤드 개수 설정)
projection_dim = 64
num_heads = 4

# 트랜스포머 블록 내부의 레이어 유닛 개수 설정
transformer_units = [
    projection_dim * 2,
    projection_dim
]

# 트랜스포머 블록의 층 수 설정
transformer_layers = 12

# MLP 헤드 내부의 레이어 유닛 개수 설정
mlp_head_units = [2048, 1024]

# %%
# 데이터 증강을 위한 Keras Sequential 모델을 생성
data_augmentation = tf.keras.Sequential(
    [
        layers.Normalization(),           # 데이터 정규화 (이미지 픽셀 값을 [0, 1] 범위로 조정)
        layers.Resizing(image_size, image_size),       # 이미지 크기를 조정
        layers.RandomFlip('horizontal'),                      # 수평 방향으로 이미지를 무작위로 뒤집기
        layers.RandomRotation(factor=0.02),             # 이미지를 무작위로 회전 (회전 범위는 ±2%)
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),  # 이미지를 무작위로 확대/축소 (높이와 너비 각각 최대 20%까지)
    ],
    name = 'data_augmentation',              # 이 Sequential 모델의 이름을 'data_augmentation'으로 설정
)

# X_train 데이터셋을 사용하여 정규화 층의 상태를 적응시킵니다.
# 즉, 데이터셋의 평균과 표준편차를 계산하여 정규화 층에 저장합니다.
data_augmentation.layers[0].adapt(X_train)

# %%
# MLP (다층 퍼셉트론) 함수 정의
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %% [markdown]
#  `tf.image.extract_patches`는 주어진 이미지에서 작은 패치들을 추출
#
# 1. **images**:  `[batch size, height, width, channels]`
# 2. **sizes**: 추출하고자 하는 패치의 크기. `[1, size_rows, size_cols, 1]`의 shape.
#     첫번째 1: batch dimension. 이 함수에서는 한 배치 내에서 한 이미지만 처리하기 때문에 1로 설정.
#     size_rows: 패치의 행 크기.
#     size_cols: 패치의 열 크기.
#     마지막 1: 이미지의 채널 수. tf.image.extract_patches 함수에서는 모든 채널에 대한 패치를 동시에 추출하기 때문에 이 값은 항상 1로 설정.
#
# 3. **strides**: 두 연속적인 패치의 중심 간의 간격을 나타내는 4차원 텐서입니다. `[1, stride_rows, stride_cols, 1]`의 형태를 가지며, 실질적으로 `stride_rows`와 `stride_cols`만 주요하게 사용됩니다.
#
# 4. **rates**: 패치 추출 시 샘플링 간격을 조절.  `[1, 1, 1, 1]` 값은 일반적인 샘플링을 의미.
#
# 5. **padding**:  'VALID'는 이미지 내에서 완전히 포함된 패치만 포함

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        # 입력 이미지의 배치 크기를 가져옴
        batch_size = tf.shape(images)[0]
        # 이미지에서 패치를 추출
        patches = tf.image.extract_patches(
            images = images,
            # 패치의 크기를 지정
            sizes = [1, self.patch_size, self.patch_size, 1],
            # 패치를 추출할 때의 간격을 지정
            strides = [1, self.patch_size, self.patch_size, 1],
            # 패치 추출 시의 비율을 지정 (변경 없음)
            rates = [1, 1, 1, 1],
            # 패딩 방식을 지정 (추출되는 패치가 이미지 경계 내에 완전히 있어야 함)
            padding="VALID",
        )
        # 추출된 패치의 차원을 가져옴 --> (batch_size, 7, 7, 3072)
        patch_dims = patches.shape[-1]
        # 패치의 형태를 reshape하여 반환 --> (batch_size, 49, 3072)
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %% [markdown]
# ### 학습 데이터 시각화
# 본래의 32X32 image를 224X224 로 resize 하였으므로 사진이 흐릿하게 보일것임.

# %%
plt.figure(figsize=(4, 4))

# 학습 데이터셋에서 랜덤하게 이미지 하나를 선택
image = X_train[np.random.choice(range(X_train.shape[0]))]

# 선택된 이미지 시각화
plt.imshow(image.astype('uint8'))
plt.axis('off')

# 이미지의 크기 조절
resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)

# Patches 클래스의 인스턴스를 생성하고 resized_image를 통과시켜 패치들을 생성
patches = Patches(patch_size)(resized_image)

# 이미지와 패치의 정보 출력
print(f'Image 크기: {image_size} X {image_size}')
print(f'Patch 크기: {patch_size} X {patch_size}')
print(f'이미지당 patch 수: {patches.shape[1]}')
print(f'patch당 element 갯수: {patches.shape[-1]}')
print(f'Shape of patch: {patches.shape}')

# 패치들을 시각화
# 패치들의 수의 제곱근으로 n 설정 (예: 패치가 16개라면 4x4로 시각화)
n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i+1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype('uint8'))
    plt.axis('off')
# Out:
# Image 크기: 224 X 224
# Patch 크기: 32 X 32
# 이미지당 patch 수: 49
# patch당 element 갯수: 3072
# Shape of patch: (1, 49, 3072)

# %% [markdown]
# ### PatchEncoder 정의
# - Vision Transformer (ViT) 모델의 핵심 구성 요소 중 하나인 PatchEncoder 클래스를 정의
# - 이 클래스는 패치를 인코딩하고 위치 정보를 임베딩

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches  # 전체 패치의 수 저장

        # 실수 값을 입력으로 받아 선형 변환을 수행하여 projection_dim으로 투영
        self.projection = layers.Dense(projection_dim)

        # 정수 인덱스를 입력으로 받아 해당 인덱스에 대응되는 임베딩 벡터 출력
        self.position_embedding = layers.Embedding(
            input_dim=num_patches,  # 입력 차원은 전체 패치의 수와 동일
            output_dim=projection_dim  # 출력 차원은 projection_dim과 동일
        )

    def call(self, patch):
        # 예: num_patches = 5 -> position = [0, 1, 2, 3, 4]
        position = tf.range(start=0, limit=self.num_patches, delta=1)

        # 패치를 투영하고 위치 임베딩을 더해 최종 인코딩된 결과를 반환
        encoded = self.projection(patch) + self.position_embedding(position)

        return encoded

# %% [markdown]
# <img src="https://viso.ai/wp-content/uploads/2021/09/vision-transformer-vit.png" width=700 />

# %%
def vit():
    inputs = layers.Input(shape=input_shape)
    # 데이터 증강 레이어를 통과
    augmented = data_augmentation(inputs)
    # 입력 이미지를 패치로 분할
    patches = Patches(patch_size)(augmented)
    # 패치 인코더를 통해 패치를 임베딩
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Transformer 블록을 transformer_layers 횟수만큼 반복
    for _ in range(transformer_layers):
        # Layer Normalization 적용
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # 멀티 헤드 어텐션 적용
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # 어텐션 결과와 인코딩된 패치를 더함
        x2 = layers.Add()([attention_output, encoded_patches])
        # 또 다시 Layer Normalization 적용
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP 적용
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # MLP 결과와 x2를 더함
        encoded_patches = layers.Add()([x3, x2])

    # 임베딩된 패치에 Layer Normalization 적용
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    # 텐서를 1차원으로 펼침
    representation = layers.Flatten()(representation)
    # Dropout 적용
    representation = layers.Dropout(0.5)(representation)
    # MLP를 사용하여 특징 추출
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # 마지막 Dense 레이어를 통해 로짓을 계산
    logits = layers.Dense(num_classes)(features)
    # 모델을 생성하고 반환
    model = tf.keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
model = vit()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  data_augmentation (Sequent  (None, 224, 224, 3)          7         ['input_1[0][0]']
#  ial)
#
#  patches_1 (Patches)         (None, None, 3072)           0         ['data_augmentation[0][0]']
#
#  patch_encoder (PatchEncode  (None, 49, 64)               199808    ['patches_1[0][0]']
#  r)
#
#  layer_normalization (Layer  (None, 49, 64)               128       ['patch_encoder[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 49, 64)               66368     ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  add (Add)                   (None, 49, 64)               0         ['multi_head_attention[0][0]',
#                                                                      'patch_encoder[0][0]']
#
#  layer_normalization_1 (Lay  (None, 49, 64)               128       ['add[0][0]']
#  erNormalization)
#
#  dense_1 (Dense)             (None, 49, 128)              8320      ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 49, 128)              0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 49, 64)               8256      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 49, 64)               0         ['dense_2[0][0]']
#
#  add_1 (Add)                 (None, 49, 64)               0         ['dropout_1[0][0]',
#                                                                      'add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 49, 64)               128       ['add_1[0][0]']
#  erNormalization)
#
#  multi_head_attention_1 (Mu  (None, 49, 64)               66368     ['layer_normalization_2[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_2[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 49, 64)               0         ['multi_head_attention_1[0][0]
#                                                                     ',
#                                                                      'add_1[0][0]']
#
#  layer_normalization_3 (Lay  (None, 49, 64)               128       ['add_2[0][0]']
#  erNormalization)
#
#  dense_3 (Dense)             (None, 49, 128)              8320      ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_2 (Dropout)         (None, 49, 128)              0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 49, 64)               8256      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 49, 64)               0         ['dense_4[0][0]']
#
#  add_3 (Add)                 (None, 49, 64)               0         ['dropout_3[0][0]',
#                                                                      'add_2[0][0]']
#
#  layer_normalization_4 (Lay  (None, 49, 64)               128       ['add_3[0][0]']
#  erNormalization)
#
#  multi_head_attention_2 (Mu  (None, 49, 64)               66368     ['layer_normalization_4[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_4[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 49, 64)               0         ['multi_head_attention_2[0][0]
#                                                                     ',
#                                                                      'add_3[0][0]']
#
#  layer_normalization_5 (Lay  (None, 49, 64)               128       ['add_4[0][0]']
#  erNormalization)
#
#  dense_5 (Dense)             (None, 49, 128)              8320      ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 49, 128)              0         ['dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 49, 64)               8256      ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 49, 64)               0         ['dense_6[0][0]']
#
#  add_5 (Add)                 (None, 49, 64)               0         ['dropout_5[0][0]',
#                                                                      'add_4[0][0]']
#
#  layer_normalization_6 (Lay  (None, 49, 64)               128       ['add_5[0][0]']
#  erNormalization)
#
#  multi_head_attention_3 (Mu  (None, 49, 64)               66368     ['layer_normalization_6[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_6[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 49, 64)               0         ['multi_head_attention_3[0][0]
#                                                                     ',
#                                                                      'add_5[0][0]']
#
#  layer_normalization_7 (Lay  (None, 49, 64)               128       ['add_6[0][0]']
#  erNormalization)
#
#  dense_7 (Dense)             (None, 49, 128)              8320      ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 49, 128)              0         ['dense_7[0][0]']
#
#  dense_8 (Dense)             (None, 49, 64)               8256      ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)         (None, 49, 64)               0         ['dense_8[0][0]']
#
#  add_7 (Add)                 (None, 49, 64)               0         ['dropout_7[0][0]',
#                                                                      'add_6[0][0]']
#
#  layer_normalization_8 (Lay  (None, 49, 64)               128       ['add_7[0][0]']
#  erNormalization)
#
#  multi_head_attention_4 (Mu  (None, 49, 64)               66368     ['layer_normalization_8[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_8[0][0]
#                                                                     ']
#
#  add_8 (Add)                 (None, 49, 64)               0         ['multi_head_attention_4[0][0]
#                                                                     ',
#                                                                      'add_7[0][0]']
#
#  layer_normalization_9 (Lay  (None, 49, 64)               128       ['add_8[0][0]']
#  erNormalization)
#
#  dense_9 (Dense)             (None, 49, 128)              8320      ['layer_normalization_9[0][0]'
#                                                                     ]
#
#  dropout_8 (Dropout)         (None, 49, 128)              0         ['dense_9[0][0]']
#
#  dense_10 (Dense)            (None, 49, 64)               8256      ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)         (None, 49, 64)               0         ['dense_10[0][0]']
#
#  add_9 (Add)                 (None, 49, 64)               0         ['dropout_9[0][0]',
#                                                                      'add_8[0][0]']
#
#  layer_normalization_10 (La  (None, 49, 64)               128       ['add_9[0][0]']
#  yerNormalization)
#
#  multi_head_attention_5 (Mu  (None, 49, 64)               66368     ['layer_normalization_10[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_10[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 49, 64)               0         ['multi_head_attention_5[0][0]
#                                                                     ',
#                                                                      'add_9[0][0]']
#
#  layer_normalization_11 (La  (None, 49, 64)               128       ['add_10[0][0]']
#  yerNormalization)
#
#  dense_11 (Dense)            (None, 49, 128)              8320      ['layer_normalization_11[0][0]
#                                                                     ']
#
#  dropout_10 (Dropout)        (None, 49, 128)              0         ['dense_11[0][0]']
#
#  dense_12 (Dense)            (None, 49, 64)               8256      ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)        (None, 49, 64)               0         ['dense_12[0][0]']
#
#  add_11 (Add)                (None, 49, 64)               0         ['dropout_11[0][0]',
#                                                                      'add_10[0][0]']
#
#  layer_normalization_12 (La  (None, 49, 64)               128       ['add_11[0][0]']
#  yerNormalization)
#
#  multi_head_attention_6 (Mu  (None, 49, 64)               66368     ['layer_normalization_12[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_12[0][0]
#                                                                     ']
#
#  add_12 (Add)                (None, 49, 64)               0         ['multi_head_attention_6[0][0]
#                                                                     ',
#                                                                      'add_11[0][0]']
#
#  layer_normalization_13 (La  (None, 49, 64)               128       ['add_12[0][0]']
#  yerNormalization)
#
#  dense_13 (Dense)            (None, 49, 128)              8320      ['layer_normalization_13[0][0]
#                                                                     ']
#
#  dropout_12 (Dropout)        (None, 49, 128)              0         ['dense_13[0][0]']
#
#  dense_14 (Dense)            (None, 49, 64)               8256      ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)        (None, 49, 64)               0         ['dense_14[0][0]']
#
#  add_13 (Add)                (None, 49, 64)               0         ['dropout_13[0][0]',
#                                                                      'add_12[0][0]']
#
#  layer_normalization_14 (La  (None, 49, 64)               128       ['add_13[0][0]']
#  yerNormalization)
#
#  multi_head_attention_7 (Mu  (None, 49, 64)               66368     ['layer_normalization_14[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_14[0][0]
#                                                                     ']
#
#  add_14 (Add)                (None, 49, 64)               0         ['multi_head_attention_7[0][0]
#                                                                     ',
#                                                                      'add_13[0][0]']
#
#  layer_normalization_15 (La  (None, 49, 64)               128       ['add_14[0][0]']
#  yerNormalization)
#
#  dense_15 (Dense)            (None, 49, 128)              8320      ['layer_normalization_15[0][0]
#                                                                     ']
#
#  dropout_14 (Dropout)        (None, 49, 128)              0         ['dense_15[0][0]']
#
#  dense_16 (Dense)            (None, 49, 64)               8256      ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)        (None, 49, 64)               0         ['dense_16[0][0]']
#
#  add_15 (Add)                (None, 49, 64)               0         ['dropout_15[0][0]',
#                                                                      'add_14[0][0]']
#
#  layer_normalization_16 (La  (None, 49, 64)               128       ['add_15[0][0]']
#  yerNormalization)
#
#  multi_head_attention_8 (Mu  (None, 49, 64)               66368     ['layer_normalization_16[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_16[0][0]
#                                                                     ']
#
#  add_16 (Add)                (None, 49, 64)               0         ['multi_head_attention_8[0][0]
#                                                                     ',
#                                                                      'add_15[0][0]']
#
#  layer_normalization_17 (La  (None, 49, 64)               128       ['add_16[0][0]']
#  yerNormalization)
#
#  dense_17 (Dense)            (None, 49, 128)              8320      ['layer_normalization_17[0][0]
#                                                                     ']
#
#  dropout_16 (Dropout)        (None, 49, 128)              0         ['dense_17[0][0]']
#
#  dense_18 (Dense)            (None, 49, 64)               8256      ['dropout_16[0][0]']
#
#  dropout_17 (Dropout)        (None, 49, 64)               0         ['dense_18[0][0]']
#
#  add_17 (Add)                (None, 49, 64)               0         ['dropout_17[0][0]',
#                                                                      'add_16[0][0]']
#
#  layer_normalization_18 (La  (None, 49, 64)               128       ['add_17[0][0]']
#  yerNormalization)
#
#  multi_head_attention_9 (Mu  (None, 49, 64)               66368     ['layer_normalization_18[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_18[0][0]
#                                                                     ']
#
#  add_18 (Add)                (None, 49, 64)               0         ['multi_head_attention_9[0][0]
#                                                                     ',
#                                                                      'add_17[0][0]']
#
#  layer_normalization_19 (La  (None, 49, 64)               128       ['add_18[0][0]']
#  yerNormalization)
#
#  dense_19 (Dense)            (None, 49, 128)              8320      ['layer_normalization_19[0][0]
#                                                                     ']
#
#  dropout_18 (Dropout)        (None, 49, 128)              0         ['dense_19[0][0]']
#
#  dense_20 (Dense)            (None, 49, 64)               8256      ['dropout_18[0][0]']
#
#  dropout_19 (Dropout)        (None, 49, 64)               0         ['dense_20[0][0]']
#
#  add_19 (Add)                (None, 49, 64)               0         ['dropout_19[0][0]',
#                                                                      'add_18[0][0]']
#
#  layer_normalization_20 (La  (None, 49, 64)               128       ['add_19[0][0]']
#  yerNormalization)
#
#  multi_head_attention_10 (M  (None, 49, 64)               66368     ['layer_normalization_20[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_20[0][0]
#                                                                     ']
#
#  add_20 (Add)                (None, 49, 64)               0         ['multi_head_attention_10[0][0
#                                                                     ]',
#                                                                      'add_19[0][0]']
#
#  layer_normalization_21 (La  (None, 49, 64)               128       ['add_20[0][0]']
#  yerNormalization)
#
#  dense_21 (Dense)            (None, 49, 128)              8320      ['layer_normalization_21[0][0]
#                                                                     ']
#
#  dropout_20 (Dropout)        (None, 49, 128)              0         ['dense_21[0][0]']
#
#  dense_22 (Dense)            (None, 49, 64)               8256      ['dropout_20[0][0]']
#
#  dropout_21 (Dropout)        (None, 49, 64)               0         ['dense_22[0][0]']
#
#  add_21 (Add)                (None, 49, 64)               0         ['dropout_21[0][0]',
#                                                                      'add_20[0][0]']
#
#  layer_normalization_22 (La  (None, 49, 64)               128       ['add_21[0][0]']
#  yerNormalization)
#
#  multi_head_attention_11 (M  (None, 49, 64)               66368     ['layer_normalization_22[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_22[0][0]
#                                                                     ']
#
#  add_22 (Add)                (None, 49, 64)               0         ['multi_head_attention_11[0][0
#                                                                     ]',
#                                                                      'add_21[0][0]']
#
#  layer_normalization_23 (La  (None, 49, 64)               128       ['add_22[0][0]']
#  yerNormalization)
#
#  dense_23 (Dense)            (None, 49, 128)              8320      ['layer_normalization_23[0][0]
#                                                                     ']
#
#  dropout_22 (Dropout)        (None, 49, 128)              0         ['dense_23[0][0]']
#
#  dense_24 (Dense)            (None, 49, 64)               8256      ['dropout_22[0][0]']
#
#  dropout_23 (Dropout)        (None, 49, 64)               0         ['dense_24[0][0]']
#
#  add_23 (Add)                (None, 49, 64)               0         ['dropout_23[0][0]',
#                                                                      'add_22[0][0]']
#
#  layer_normalization_24 (La  (None, 49, 64)               128       ['add_23[0][0]']
#  yerNormalization)
#
#  flatten (Flatten)           (None, 3136)                 0         ['layer_normalization_24[0][0]
#                                                                     ']
#
#  dropout_24 (Dropout)        (None, 3136)                 0         ['flatten[0][0]']
#
#  dense_25 (Dense)            (None, 2048)                 6424576   ['dropout_24[0][0]']
#
#  dropout_25 (Dropout)        (None, 2048)                 0         ['dense_25[0][0]']
#
#  dense_26 (Dense)            (None, 1024)                 2098176   ['dropout_25[0][0]']
#
#  dropout_26 (Dropout)        (None, 1024)                 0         ['dense_26[0][0]']
#
#  dense_27 (Dense)            (None, 100)                  102500    ['dropout_26[0][0]']
#
# ==================================================================================================
# Total params: 9823595 (37.47 MB)
# Trainable params: 9823588 (37.47 MB)
# Non-trainable params: 7 (32.00 Byte)
# __________________________________________________________________________________________________

# %%
plot_model(model)

# %% [markdown]
# Top-k 정확도는 다중 클래스 분류 문제에서 모델의 성능을 측정하는 지표 중 하나로, 모델이 예측한 클래스 중 상위 k개의 예측 중에 정답 클래스가 포함된 비율.  주로 이미지 분류와 같이 클래스 수가 많고 모델이 상위 몇 개의 가능성 있는 클래스를 예측할 수 있는 경우에 유용.

# %%
# %%time
num_epochs = 20          # 에포크 수 (전체 데이터셋 학습 횟수)
weight_decay = 0.001     # 가중치 감소 값
learning_rate = 0.001    # 학습률

optimizer = Adam(learning_rate=learning_rate)

model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[
        tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy'),
        tf.keras.metrics.SparseTopKCategoricalAccuracy(5, name='top-5-accuracy')  # 상위 5개 예측 내에서의 정확도
    ]
    )

# 모델 학습
history = model.fit(
    x = X_train, y=y_train,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_split=0.1
)
# Out:
# Epoch 1/20
# 176/176 [==============================] - 83s 188ms/step - loss: 4.3915 - accuracy: 0.0533 - top-5-accuracy: 0.1811 - val_loss: 3.8608 - val_accuracy: 0.1168 - val_top-5-accuracy: 0.3264
# Epoch 2/20
# 176/176 [==============================] - 32s 181ms/step - loss: 3.9231 - accuracy: 0.0985 - top-5-accuracy: 0.2969 - val_loss: 3.5533 - val_accuracy: 0.1654 - val_top-5-accuracy: 0.4116
# Epoch 3/20
# 176/176 [==============================] - 32s 183ms/step - loss: 3.7087 - accuracy: 0.1303 - top-5-accuracy: 0.3628 - val_loss: 3.3910 - val_accuracy: 0.1888 - val_top-5-accuracy: 0.4624
# Epoch 4/20
# 176/176 [==============================] - 32s 185ms/step - loss: 3.5401 - accuracy: 0.1553 - top-5-accuracy: 0.4128 - val_loss: 3.2464 - val_accuracy: 0.2134 - val_top-5-accuracy: 0.4916
# Epoch 5/20
# 176/176 [==============================] - 33s 186ms/step - loss: 3.4287 - accuracy: 0.1782 - top-5-accuracy: 0.4449 - val_loss: 3.1466 - val_accuracy: 0.2282 - val_top-5-accuracy: 0.5104
# Epoch 6/20
# 176/176 [==============================] - 34s 193ms/step - loss: 3.3227 - accuracy: 0.1946 - top-5-accuracy: 0.4737 - val_loss: 3.0709 - val_accuracy: 0.2494 - val_top-5-accuracy: 0.5344
# Epoch 7/20
# 176/176 [==============================] - 33s 186ms/step - loss: 3.2368 - accuracy: 0.2110 - top-5-accuracy: 0.4926 - val_loss: 2.9642 - val_accuracy: 0.2632 - val_top-5-accuracy: 0.5610
# Epoch 8/20
# 176/176 [==============================] - 33s 185ms/step - loss: 3.1543 - accuracy: 0.2274 - top-5-accuracy: 0.5146 - val_loss: 2.9077 - val_accuracy: 0.2780 - val_top-5-accuracy: 0.5750
# Epoch 9/20
# 176/176 [==============================] - 33s 185ms/step - loss: 3.0735 - accuracy: 0.2429 - top-5-accuracy: 0.5340 - val_loss: 2.8366 - val_accuracy: 0.2880 - val_top-5-accuracy: 0.5916
# Epoch 10/20
# 176/176 [==============================] - 32s 184ms/step - loss: 3.0073 - accuracy: 0.2521 - top-5-accuracy: 0.5534 - val_loss: 2.7710 - val_accuracy: 0.3074 - val_top-5-accuracy: 0.6056
# Epoch 11/20
# 176/176 [==============================] - 33s 185ms/step - loss: 2.9377 - accuracy: 0.2684 - top-5-accuracy: 0.5717 - val_loss: 2.7386 - val_accuracy: 0.3116 - val_top-5-accuracy: 0.6170
# Epoch 12/20
# 176/176 [==============================] - 33s 185ms/step - loss: 2.8789 - accuracy: 0.2770 - top-5-accuracy: 0.5836 - val_loss: 2.7175 - val_accuracy: 0.3254 - val_top-5-accuracy: 0.6202
# Epoch 13/20
# 176/176 [==============================] - 32s 184ms/step - loss: 2.8348 - accuracy: 0.2891 - top-5-accuracy: 0.5950 - val_loss: 2.6095 - val_accuracy: 0.3344 - val_top-5-accuracy: 0.6436
# Epoch 14/20
# 176/176 [==============================] - 33s 186ms/step - loss: 2.7736 - accuracy: 0.3004 - top-5-accuracy: 0.6069 - val_loss: 2.5863 - val_accuracy: 0.3394 - val_top-5-accuracy: 0.6452
# Epoch 15/20
# 176/176 [==============================] - 33s 185ms/step - loss: 2.7214 - accuracy: 0.3107 - top-5-accuracy: 0.6198 - val_loss: 2.5360 - val_accuracy: 0.3488 - val_top-5-accuracy: 0.6552
# Epoch 16/20
# 176/176 [==============================] - 33s 185ms/step - loss: 2.6727 - accuracy: 0.3192 - top-5-accuracy: 0.6325 - val_loss: 2.4951 - val_accuracy: 0.3632 - val_top-5-accuracy: 0.6658
# Epoch 17/20
# 176/176 [==============================] - 33s 186ms/step - loss: 2.6084 - accuracy: 0.3328 - top-5-accuracy: 0.6493 - val_loss: 2.4548 - val_accuracy: 0.3718 - val_top-5-accuracy: 0.6808
# Epoch 18/20
# 176/176 [==============================] - 33s 185ms/step - loss: 2.5580 - accuracy: 0.3418 - top-5-accuracy: 0.6598 - val_loss: 2.4202 - val_accuracy: 0.3822 - val_top-5-accuracy: 0.6876
# Epoch 19/20
# 176/176 [==============================] - 33s 185ms/step - loss: 2.5197 - accuracy: 0.3505 - top-5-accuracy: 0.6661 - val_loss: 2.3697 - val_accuracy: 0.3890 - val_top-5-accuracy: 0.6954
# Epoch 20/20
# 176/176 [==============================] - 33s 185ms/step - loss: 2.4697 - accuracy: 0.3621 - top-5-accuracy: 0.6771 - val_loss: 2.3774 - val_accuracy: 0.3874 - val_top-5-accuracy: 0.6934
# CPU times: user 8min 21s, sys: 48.2 s, total: 9min 9s
# Wall time: 11min 43s

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b--', label='loss')
plt.plot(history.history['val_loss'], 'r', label='val_loss')
plt.xlabel('Epochs')
plt.grid()
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'b--', label='accuracy')
plt.plot(history.history['val_accuracy'], 'r', label='val_accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend()

# %% [markdown]
# ### 단순 accuracy 계산

# %%
from sklearn.metrics import accuracy_score

y_pred  = model.predict(X_test).argmax(axis=-1)

accuracy_score(y_test, y_pred)
# Out:
# 313/313 [==============================] - 8s 26ms/step
# 0.3949

# %% [markdown]
# ### Top-5 accuracy 계산

# %%
# 예측값의 top-5를 구하는 함수
def top_k_accuracy(y_true, y_pred, k=5):
    top_k_preds = np.argsort(y_pred, axis=-1)[:, -k:]  # 각 예측에 대해 상위 k개의 인덱스를 가져옴
    matches = np.any(top_k_preds == y_test, axis=-1)  # 실제 값이 top-5에 있는지 확인
    accuracy = np.mean(matches)  # 정확도 계산
    return accuracy

# 예측값을 얻음
y_pred = model.predict(X_test)

# 실제 값과 예측값을 이용해 top-5 accuracy를 계산
accuracy = top_k_accuracy(y_test, y_pred, k=5)

print(f"Top-5 Accuracy: {accuracy:.4f}")
# Out:
# 313/313 [==============================] - 7s 23ms/step
# Top-5 Accuracy: 0.6931

# %% [markdown]
# ### 논문의 benchmark 결과에 의하면 Cifar100 에서 94% 이상의 accuracy 달성
